# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.9046104802746175, score: 26
# Scores: (min: 14, avg: 20, max: 26)
#
# Run: 3, exploration: 0.810157377815473, score: 23
# Scores: (min: 14, avg: 21, max: 26)
#
# Run: 4, exploration: 0.6401093727576664, score: 48
# Scores: (min: 14, avg: 27.75, max: 48)
#
# Run: 5, exploration: 0.547986285490042, score: 32
# Scores: (min: 14, avg: 28.6, max: 48)
#
# Run: 6, exploration: 0.3063705780533402, score: 117
# Scores: (min: 14, avg: 43.333333333333336, max: 117)
#
# Run: 7, exploration: 0.2730095965279488, score: 24
# Scores: (min: 14, avg: 40.57142857142857, max: 117)
#
# Run: 8, exploration: 0.2494556624678441, score: 19
# Scores: (min: 14, avg: 37.875, max: 117)
#
# Run: 9, exploration: 0.22793384675362674, score: 19
# Scores: (min: 14, avg: 35.77777777777778, max: 117)
#
# Run: 10, exploration: 0.192217783647157, score: 35
# Scores: (min: 14, avg: 35.7, max: 117)
#
# Run: 11, exploration: 0.17388222158237718, score: 21
# Scores: (min: 14, avg: 34.36363636363637, max: 117)
#
# Run: 12, exploration: 0.14300635237083656, score: 40
# Scores: (min: 14, avg: 34.833333333333336, max: 117)
#
# Run: 13, exploration: 0.10964241905397228, score: 54
# Scores: (min: 14, avg: 36.30769230769231, max: 117)
#
# Run: 14, exploration: 0.0943346041173244, score: 31
# Scores: (min: 14, avg: 35.92857142857143, max: 117)
#
# Run: 15, exploration: 0.07797369223798889, score: 39
# Scores: (min: 14, avg: 36.13333333333333, max: 117)
#
# Run: 16, exploration: 0.0609928681304848, score: 50
# Scores: (min: 14, avg: 37, max: 117)
#
# Run: 17, exploration: 0.05143559895690903, score: 35
# Scores: (min: 14, avg: 36.88235294117647, max: 117)
#
# Run: 18, exploration: 0.04272851397543923, score: 38
# Scores: (min: 14, avg: 36.94444444444444, max: 117)
#
# Run: 19, exploration: 0.03479077471386296, score: 42
# Scores: (min: 14, avg: 37.21052631578947, max: 117)
#
# Run: 20, exploration: 0.0280450728002803, score: 44
# Scores: (min: 14, avg: 37.55, max: 117)
#
# Run: 21, exploration: 0.02171869316274056, score: 52
# Scores: (min: 14, avg: 38.23809523809524, max: 117)
#
# Run: 22, exploration: 0.01283090141222608, score: 106
# Scores: (min: 14, avg: 41.31818181818182, max: 117)
#
# Run: 23, exploration: 0.011206767143558775, score: 28
# Scores: (min: 14, avg: 40.73913043478261, max: 117)
#
# Run: 24, exploration: 0.01, score: 34
# Scores: (min: 14, avg: 40.458333333333336, max: 117)
#
# Run: 25, exploration: 0.01, score: 106
# Scores: (min: 14, avg: 43.08, max: 117)
#
# Run: 26, exploration: 0.01, score: 91
# Scores: (min: 14, avg: 44.92307692307692, max: 117)
#
# Run: 27, exploration: 0.01, score: 279
# Scores: (min: 14, avg: 53.592592592592595, max: 279)
#
# Run: 28, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 56.17857142857143, max: 279)
#
# Run: 29, exploration: 0.01, score: 142
# Scores: (min: 14, avg: 59.13793103448276, max: 279)
#
# Run: 30, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 62.36666666666667, max: 279)
#
# Run: 31, exploration: 0.01, score: 273
# Scores: (min: 14, avg: 69.16129032258064, max: 279)
#
# Run: 32, exploration: 0.01, score: 161
# Scores: (min: 14, avg: 72.03125, max: 279)
#
# Run: 33, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 75.06060606060606, max: 279)
#
# Run: 34, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 77.79411764705883, max: 279)
#
# Run: 35, exploration: 0.01, score: 139
# Scores: (min: 14, avg: 79.54285714285714, max: 279)
#
# Run: 36, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 80.83333333333333, max: 279)
#
# Run: 37, exploration: 0.01, score: 105
# Scores: (min: 14, avg: 81.48648648648648, max: 279)
#
# Run: 38, exploration: 0.01, score: 158
# Scores: (min: 14, avg: 83.5, max: 279)
#
# Run: 39, exploration: 0.01, score: 142
# Scores: (min: 14, avg: 85, max: 279)
#
# Run: 40, exploration: 0.01, score: 152
# Scores: (min: 14, avg: 86.675, max: 279)
#
# Run: 41, exploration: 0.01, score: 198
# Scores: (min: 14, avg: 89.39024390243902, max: 279)
#
# Run: 42, exploration: 0.01, score: 157
# Scores: (min: 14, avg: 91, max: 279)
#
# Run: 43, exploration: 0.01, score: 162
# Scores: (min: 14, avg: 92.65116279069767, max: 279)
#
# Run: 44, exploration: 0.01, score: 200
# Scores: (min: 14, avg: 95.0909090909091, max: 279)
#
# Run: 45, exploration: 0.01, score: 138
# Scores: (min: 14, avg: 96.04444444444445, max: 279)
#
# Run: 46, exploration: 0.01, score: 189
# Scores: (min: 14, avg: 98.06521739130434, max: 279)
#
# Run: 47, exploration: 0.01, score: 148
# Scores: (min: 14, avg: 99.12765957446808, max: 279)
#
# Run: 48, exploration: 0.01, score: 132
# Scores: (min: 14, avg: 99.8125, max: 279)
#
# Run: 49, exploration: 0.01, score: 160
# Scores: (min: 14, avg: 101.04081632653062, max: 279)
#
# Run: 50, exploration: 0.01, score: 185
# Scores: (min: 14, avg: 102.72, max: 279)
#
# Run: 51, exploration: 0.01, score: 146
# Scores: (min: 14, avg: 103.56862745098039, max: 279)
#
# Run: 52, exploration: 0.01, score: 159
# Scores: (min: 14, avg: 104.63461538461539, max: 279)
#
# Run: 53, exploration: 0.01, score: 164
# Scores: (min: 14, avg: 105.75471698113208, max: 279)
#
# Run: 54, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 106.98148148148148, max: 279)
#
# Run: 55, exploration: 0.01, score: 144
# Scores: (min: 14, avg: 107.65454545454546, max: 279)
#
# Run: 56, exploration: 0.01, score: 118
# Scores: (min: 14, avg: 107.83928571428571, max: 279)
#
# Run: 57, exploration: 0.01, score: 149
# Scores: (min: 14, avg: 108.56140350877193, max: 279)
#
# Run: 58, exploration: 0.01, score: 164
# Scores: (min: 14, avg: 109.51724137931035, max: 279)
#
# Run: 59, exploration: 0.01, score: 120
# Scores: (min: 14, avg: 109.69491525423729, max: 279)
#
# Run: 60, exploration: 0.01, score: 162
# Scores: (min: 14, avg: 110.56666666666666, max: 279)
#
# Run: 61, exploration: 0.01, score: 132
# Scores: (min: 14, avg: 110.91803278688525, max: 279)
#
# Run: 62, exploration: 0.01, score: 125
# Scores: (min: 14, avg: 111.14516129032258, max: 279)
#
# Run: 63, exploration: 0.01, score: 128
# Scores: (min: 14, avg: 111.41269841269842, max: 279)
#
# Run: 64, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 111.71875, max: 279)
#
# Run: 65, exploration: 0.01, score: 166
# Scores: (min: 14, avg: 112.55384615384615, max: 279)
#
# Run: 66, exploration: 0.01, score: 151
# Scores: (min: 14, avg: 113.13636363636364, max: 279)
#
# Run: 67, exploration: 0.01, score: 138
# Scores: (min: 14, avg: 113.50746268656717, max: 279)
#
# Run: 68, exploration: 0.01, score: 181
# Scores: (min: 14, avg: 114.5, max: 279)
#
# Run: 69, exploration: 0.01, score: 136
# Scores: (min: 14, avg: 114.81159420289855, max: 279)
#
# Run: 70, exploration: 0.01, score: 100
# Scores: (min: 14, avg: 114.6, max: 279)
#
# Run: 71, exploration: 0.01, score: 165
# Scores: (min: 14, avg: 115.30985915492958, max: 279)
#
# Run: 72, exploration: 0.01, score: 142
# Scores: (min: 14, avg: 115.68055555555556, max: 279)
#
# Run: 73, exploration: 0.01, score: 122
# Scores: (min: 14, avg: 115.76712328767124, max: 279)
#
# Run: 74, exploration: 0.01, score: 176
# Scores: (min: 14, avg: 116.58108108108108, max: 279)
#
# Run: 75, exploration: 0.01, score: 134
# Scores: (min: 14, avg: 116.81333333333333, max: 279)
#
# Run: 76, exploration: 0.01, score: 139
# Scores: (min: 14, avg: 117.10526315789474, max: 279)
#
# Run: 77, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 117.6103896103896, max: 279)
#
# Run: 78, exploration: 0.01, score: 147
# Scores: (min: 14, avg: 117.98717948717949, max: 279)
#
# Run: 79, exploration: 0.01, score: 122
# Scores: (min: 14, avg: 118.0379746835443, max: 279)
#
# Run: 80, exploration: 0.01, score: 148
# Scores: (min: 14, avg: 118.4125, max: 279)
#
# Run: 81, exploration: 0.01, score: 149
# Scores: (min: 14, avg: 118.79012345679013, max: 279)
#
# Run: 82, exploration: 0.01, score: 199
# Scores: (min: 14, avg: 119.76829268292683, max: 279)
#
# Run: 83, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 120.34939759036145, max: 279)
#
# Run: 84, exploration: 0.01, score: 165
# Scores: (min: 14, avg: 120.88095238095238, max: 279)
#
# Run: 85, exploration: 0.01, score: 69
# Scores: (min: 14, avg: 120.27058823529411, max: 279)
#
# Run: 86, exploration: 0.01, score: 216
# Scores: (min: 14, avg: 121.38372093023256, max: 279)
#
# Run: 87, exploration: 0.01, score: 127
# Scores: (min: 14, avg: 121.44827586206897, max: 279)
#
# Run: 88, exploration: 0.01, score: 138
# Scores: (min: 14, avg: 121.63636363636364, max: 279)
#
# Run: 89, exploration: 0.01, score: 195
# Scores: (min: 14, avg: 122.46067415730337, max: 279)
#
# Run: 90, exploration: 0.01, score: 155
# Scores: (min: 14, avg: 122.82222222222222, max: 279)
#
# Run: 91, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 123.31868131868131, max: 279)
#
# Run: 92, exploration: 0.01, score: 80
# Scores: (min: 14, avg: 122.84782608695652, max: 279)
#
# Run: 93, exploration: 0.01, score: 141
# Scores: (min: 14, avg: 123.04301075268818, max: 279)
#
# Run: 94, exploration: 0.01, score: 95
# Scores: (min: 14, avg: 122.74468085106383, max: 279)
#
# Run: 95, exploration: 0.01, score: 142
# Scores: (min: 14, avg: 122.94736842105263, max: 279)
#
# Run: 96, exploration: 0.01, score: 178
# Scores: (min: 14, avg: 123.52083333333333, max: 279)
#
# Run: 97, exploration: 0.01, score: 139
# Scores: (min: 14, avg: 123.68041237113403, max: 279)
#
# Run: 98, exploration: 0.01, score: 216
# Scores: (min: 14, avg: 124.62244897959184, max: 279)
#
# Run: 99, exploration: 0.01, score: 133
# Scores: (min: 14, avg: 124.70707070707071, max: 279)
#
# Run: 100, exploration: 0.01, score: 135
# Scores: (min: 14, avg: 124.81, max: 279)
#
# Run: 101, exploration: 0.01, score: 132
# Scores: (min: 19, avg: 125.99, max: 279)
#
# Run: 102, exploration: 0.01, score: 149
# Scores: (min: 19, avg: 127.22, max: 279)
#
# Run: 103, exploration: 0.01, score: 177
# Scores: (min: 19, avg: 128.76, max: 279)
#
# Run: 104, exploration: 0.01, score: 179
# Scores: (min: 19, avg: 130.07, max: 279)
#
# Run: 105, exploration: 0.01, score: 149
# Scores: (min: 19, avg: 131.24, max: 279)
#
# Run: 106, exploration: 0.01, score: 157
# Scores: (min: 19, avg: 131.64, max: 279)
#
# Run: 107, exploration: 0.01, score: 145
# Scores: (min: 19, avg: 132.85, max: 279)
#
# Run: 108, exploration: 0.01, score: 154
# Scores: (min: 19, avg: 134.2, max: 279)
#
# Run: 109, exploration: 0.01, score: 170
# Scores: (min: 21, avg: 135.71, max: 279)
#
# Run: 110, exploration: 0.01, score: 195
# Scores: (min: 21, avg: 137.31, max: 279)
#
# Run: 111, exploration: 0.01, score: 170
# Scores: (min: 28, avg: 138.8, max: 279)
#
# Run: 112, exploration: 0.01, score: 163
# Scores: (min: 28, avg: 140.03, max: 279)
#
# Run: 113, exploration: 0.01, score: 159
# Scores: (min: 28, avg: 141.08, max: 279)
#
# Run: 114, exploration: 0.01, score: 164
# Scores: (min: 28, avg: 142.41, max: 279)
#
# Run: 115, exploration: 0.01, score: 132
# Scores: (min: 28, avg: 143.34, max: 279)
#
# Run: 116, exploration: 0.01, score: 130
# Scores: (min: 28, avg: 144.14, max: 279)
#
# Run: 117, exploration: 0.01, score: 142
# Scores: (min: 28, avg: 145.21, max: 279)
#
# Run: 118, exploration: 0.01, score: 111
# Scores: (min: 28, avg: 145.94, max: 279)
#
# Run: 119, exploration: 0.01, score: 139
# Scores: (min: 28, avg: 146.91, max: 279)
#
# Run: 120, exploration: 0.01, score: 180
# Scores: (min: 28, avg: 148.27, max: 279)
#
# Run: 121, exploration: 0.01, score: 170
# Scores: (min: 28, avg: 149.45, max: 279)
#
# Run: 122, exploration: 0.01, score: 148
# Scores: (min: 28, avg: 149.87, max: 279)
#
# Run: 123, exploration: 0.01, score: 185
# Scores: (min: 34, avg: 151.44, max: 279)
#
# Run: 124, exploration: 0.01, score: 183
# Scores: (min: 69, avg: 152.93, max: 279)
#
# Run: 125, exploration: 0.01, score: 136
# Scores: (min: 69, avg: 153.23, max: 279)
#
# Run: 126, exploration: 0.01, score: 170
# Scores: (min: 69, avg: 154.02, max: 279)
#
# Run: 127, exploration: 0.01, score: 145
# Scores: (min: 69, avg: 152.68, max: 273)
#
# Run: 128, exploration: 0.01, score: 150
# Scores: (min: 69, avg: 152.92, max: 273)
#
# Run: 129, exploration: 0.01, score: 142
# Scores: (min: 69, avg: 152.92, max: 273)
#
# Run: 130, exploration: 0.01, score: 139
# Scores: (min: 69, avg: 152.75, max: 273)
#
# Run: 131, exploration: 0.01, score: 128
# Scores: (min: 69, avg: 151.3, max: 216)
#
# Run: 132, exploration: 0.01, score: 133
# Scores: (min: 69, avg: 151.02, max: 216)
#
# Run: 133, exploration: 0.01, score: 217
# Scores: (min: 69, avg: 151.47, max: 217)
#
# Run: 134, exploration: 0.01, score: 203
# Scores: (min: 69, avg: 151.82, max: 217)
#
# Run: 135, exploration: 0.01, score: 171
# Scores: (min: 69, avg: 152.14, max: 217)
#
# Run: 136, exploration: 0.01, score: 143
# Scores: (min: 69, avg: 152.31, max: 217)
#
# Run: 137, exploration: 0.01, score: 38
# Scores: (min: 38, avg: 151.64, max: 217)
#
# Run: 138, exploration: 0.01, score: 220
# Scores: (min: 38, avg: 152.26, max: 220)
#
# Run: 139, exploration: 0.01, score: 124
# Scores: (min: 38, avg: 152.08, max: 220)
#
# Run: 140, exploration: 0.01, score: 141
# Scores: (min: 38, avg: 151.97, max: 220)
#
# Run: 141, exploration: 0.01, score: 142
# Scores: (min: 38, avg: 151.41, max: 220)
#
# Run: 142, exploration: 0.01, score: 144
# Scores: (min: 38, avg: 151.28, max: 220)
#
# Run: 143, exploration: 0.01, score: 156
# Scores: (min: 38, avg: 151.22, max: 220)
#
# Run: 144, exploration: 0.01, score: 160
# Scores: (min: 38, avg: 150.82, max: 220)
#
# Run: 145, exploration: 0.01, score: 162
# Scores: (min: 38, avg: 151.06, max: 220)
#
# Run: 146, exploration: 0.01, score: 148
# Scores: (min: 38, avg: 150.65, max: 220)
#
# Run: 147, exploration: 0.01, score: 152
# Scores: (min: 38, avg: 150.69, max: 220)
#
# Run: 148, exploration: 0.01, score: 168
# Scores: (min: 38, avg: 151.05, max: 220)
#
# Run: 149, exploration: 0.01, score: 170
# Scores: (min: 38, avg: 151.15, max: 220)
#
# Run: 150, exploration: 0.01, score: 161
# Scores: (min: 38, avg: 150.91, max: 220)
#
# Run: 151, exploration: 0.01, score: 15
# Scores: (min: 15, avg: 149.6, max: 220)
#
# Run: 152, exploration: 0.01, score: 127
# Scores: (min: 15, avg: 149.28, max: 220)
#
# Run: 153, exploration: 0.01, score: 36
# Scores: (min: 15, avg: 148, max: 220)
#
# Run: 154, exploration: 0.01, score: 151
# Scores: (min: 15, avg: 147.79, max: 220)
#
# Run: 155, exploration: 0.01, score: 129
# Scores: (min: 15, avg: 147.64, max: 220)
#
# Run: 156, exploration: 0.01, score: 131
# Scores: (min: 15, avg: 147.77, max: 220)
#
# Run: 157, exploration: 0.01, score: 123
# Scores: (min: 15, avg: 147.51, max: 220)
#
# Run: 158, exploration: 0.01, score: 104
# Scores: (min: 15, avg: 146.91, max: 220)
#
# Run: 159, exploration: 0.01, score: 143
# Scores: (min: 15, avg: 147.14, max: 220)
#
# Run: 160, exploration: 0.01, score: 183
# Scores: (min: 15, avg: 147.35, max: 220)
#
# Run: 161, exploration: 0.01, score: 164
# Scores: (min: 15, avg: 147.67, max: 220)
#
# Run: 162, exploration: 0.01, score: 240
# Scores: (min: 15, avg: 148.82, max: 240)
#
# Run: 163, exploration: 0.01, score: 186
# Scores: (min: 15, avg: 149.4, max: 240)
#
# Run: 164, exploration: 0.01, score: 124
# Scores: (min: 15, avg: 149.33, max: 240)
#
# Run: 165, exploration: 0.01, score: 192
# Scores: (min: 15, avg: 149.59, max: 240)
#
# Run: 166, exploration: 0.01, score: 133
# Scores: (min: 15, avg: 149.41, max: 240)
#
# Run: 167, exploration: 0.01, score: 156
# Scores: (min: 15, avg: 149.59, max: 240)
#
# Run: 168, exploration: 0.01, score: 186
# Scores: (min: 15, avg: 149.64, max: 240)
#
# Run: 169, exploration: 0.01, score: 140
# Scores: (min: 15, avg: 149.68, max: 240)
#
# Run: 170, exploration: 0.01, score: 162
# Scores: (min: 15, avg: 150.3, max: 240)
#
# Run: 171, exploration: 0.01, score: 177
# Scores: (min: 15, avg: 150.42, max: 240)
#
# Run: 172, exploration: 0.01, score: 241
# Scores: (min: 15, avg: 151.41, max: 241)
#
# Run: 173, exploration: 0.01, score: 190
# Scores: (min: 15, avg: 152.09, max: 241)
#
# Run: 174, exploration: 0.01, score: 206
# Scores: (min: 15, avg: 152.39, max: 241)
#
# Run: 175, exploration: 0.01, score: 145
# Scores: (min: 15, avg: 152.5, max: 241)
#
# Run: 176, exploration: 0.01, score: 149
# Scores: (min: 15, avg: 152.6, max: 241)
#
# Run: 177, exploration: 0.01, score: 181
# Scores: (min: 15, avg: 152.85, max: 241)
#
# Run: 178, exploration: 0.01, score: 164
# Scores: (min: 15, avg: 153.02, max: 241)
#
# Run: 179, exploration: 0.01, score: 222
# Scores: (min: 15, avg: 154.02, max: 241)
#
# Run: 180, exploration: 0.01, score: 213
# Scores: (min: 15, avg: 154.67, max: 241)
#
# Run: 181, exploration: 0.01, score: 134
# Scores: (min: 15, avg: 154.52, max: 241)
#
# Run: 182, exploration: 0.01, score: 238
# Scores: (min: 15, avg: 154.91, max: 241)
#
# Run: 183, exploration: 0.01, score: 247
# Scores: (min: 15, avg: 155.7, max: 247)
#
# Run: 184, exploration: 0.01, score: 153
# Scores: (min: 15, avg: 155.58, max: 247)
#
# Run: 185, exploration: 0.01, score: 163
# Scores: (min: 15, avg: 156.52, max: 247)
#
# Run: 186, exploration: 0.01, score: 130
# Scores: (min: 15, avg: 155.66, max: 247)
#
# Run: 187, exploration: 0.01, score: 170
# Scores: (min: 15, avg: 156.09, max: 247)
#
# Run: 188, exploration: 0.01, score: 169
# Scores: (min: 15, avg: 156.4, max: 247)
#
# Run: 189, exploration: 0.01, score: 179
# Scores: (min: 15, avg: 156.24, max: 247)
#
# Run: 190, exploration: 0.01, score: 158
# Scores: (min: 15, avg: 156.27, max: 247)
#
# Run: 191, exploration: 0.01, score: 177
# Scores: (min: 15, avg: 156.36, max: 247)
#
# Run: 192, exploration: 0.01, score: 192
# Scores: (min: 15, avg: 157.48, max: 247)
#
# Run: 193, exploration: 0.01, score: 200
# Scores: (min: 15, avg: 158.07, max: 247)
#
# Run: 194, exploration: 0.01, score: 242
# Scores: (min: 15, avg: 159.54, max: 247)
#
# Run: 195, exploration: 0.01, score: 116
# Scores: (min: 15, avg: 159.28, max: 247)
#
# Run: 196, exploration: 0.01, score: 389
# Scores: (min: 15, avg: 161.39, max: 389)
#
# Run: 197, exploration: 0.01, score: 405
# Scores: (min: 15, avg: 164.05, max: 405)
#
# Run: 198, exploration: 0.01, score: 271
# Scores: (min: 15, avg: 164.6, max: 405)
#
# Run: 199, exploration: 0.01, score: 227
# Scores: (min: 15, avg: 165.54, max: 405)
#
# Run: 200, exploration: 0.01, score: 185
# Scores: (min: 15, avg: 166.04, max: 405)
#
# Run: 201, exploration: 0.01, score: 264
# Scores: (min: 15, avg: 167.36, max: 405)
#
# Run: 202, exploration: 0.01, score: 248
# Scores: (min: 15, avg: 168.35, max: 405)
#
# Run: 203, exploration: 0.01, score: 118
# Scores: (min: 15, avg: 167.76, max: 405)
#
# Run: 204, exploration: 0.01, score: 103
# Scores: (min: 15, avg: 167, max: 405)
#
# Run: 205, exploration: 0.01, score: 107
# Scores: (min: 15, avg: 166.58, max: 405)
#
# Run: 206, exploration: 0.01, score: 124
# Scores: (min: 15, avg: 166.25, max: 405)
#
# Run: 207, exploration: 0.01, score: 169
# Scores: (min: 15, avg: 166.49, max: 405)
#
# Run: 208, exploration: 0.01, score: 151
# Scores: (min: 15, avg: 166.46, max: 405)
#
# Run: 209, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 169.76, max: 500)
#
# Run: 210, exploration: 0.01, score: 143
# Scores: (min: 15, avg: 169.24, max: 500)
#
# Run: 211, exploration: 0.01, score: 83
# Scores: (min: 15, avg: 168.37, max: 500)
#
# Run: 212, exploration: 0.01, score: 236
# Scores: (min: 15, avg: 169.1, max: 500)
#
# Run: 213, exploration: 0.01, score: 140
# Scores: (min: 15, avg: 168.91, max: 500)
#
# Run: 214, exploration: 0.01, score: 46
# Scores: (min: 15, avg: 167.73, max: 500)
#
# Run: 215, exploration: 0.01, score: 259
# Scores: (min: 15, avg: 169, max: 500)
#
# Run: 216, exploration: 0.01, score: 128
# Scores: (min: 15, avg: 168.98, max: 500)
#
# Run: 217, exploration: 0.01, score: 92
# Scores: (min: 15, avg: 168.48, max: 500)
#
# Run: 218, exploration: 0.01, score: 338
# Scores: (min: 15, avg: 170.75, max: 500)
#
# Run: 219, exploration: 0.01, score: 164
# Scores: (min: 15, avg: 171, max: 500)
#
# Run: 220, exploration: 0.01, score: 122
# Scores: (min: 15, avg: 170.42, max: 500)
#
# Run: 221, exploration: 0.01, score: 313
# Scores: (min: 15, avg: 171.85, max: 500)
#
# Run: 222, exploration: 0.01, score: 107
# Scores: (min: 15, avg: 171.44, max: 500)
#
# Run: 223, exploration: 0.01, score: 115
# Scores: (min: 15, avg: 170.74, max: 500)
#
# Run: 224, exploration: 0.01, score: 125
# Scores: (min: 15, avg: 170.16, max: 500)
#
# Run: 225, exploration: 0.01, score: 110
# Scores: (min: 15, avg: 169.9, max: 500)
#
# Run: 226, exploration: 0.01, score: 101
# Scores: (min: 15, avg: 169.21, max: 500)
#
# Run: 227, exploration: 0.01, score: 127
# Scores: (min: 15, avg: 169.03, max: 500)
#
# Run: 228, exploration: 0.01, score: 109
# Scores: (min: 15, avg: 168.62, max: 500)
#
# Run: 229, exploration: 0.01, score: 115
# Scores: (min: 15, avg: 168.35, max: 500)
#
# Run: 230, exploration: 0.01, score: 135
# Scores: (min: 15, avg: 168.31, max: 500)
#
# Run: 231, exploration: 0.01, score: 127
# Scores: (min: 15, avg: 168.3, max: 500)
#
# Run: 232, exploration: 0.01, score: 49
# Scores: (min: 15, avg: 167.46, max: 500)
#
# Run: 233, exploration: 0.01, score: 117
# Scores: (min: 15, avg: 166.46, max: 500)
#
# Run: 234, exploration: 0.01, score: 122
# Scores: (min: 15, avg: 165.65, max: 500)
#
# Run: 235, exploration: 0.01, score: 46
# Scores: (min: 15, avg: 164.4, max: 500)
#
# Run: 236, exploration: 0.01, score: 39
# Scores: (min: 15, avg: 163.36, max: 500)
#
# Run: 237, exploration: 0.01, score: 109
# Scores: (min: 15, avg: 164.07, max: 500)
#
# Run: 238, exploration: 0.01, score: 122
# Scores: (min: 15, avg: 163.09, max: 500)
#
# Run: 239, exploration: 0.01, score: 175
# Scores: (min: 15, avg: 163.6, max: 500)
#
# Run: 240, exploration: 0.01, score: 115
# Scores: (min: 15, avg: 163.34, max: 500)
#
# Run: 241, exploration: 0.01, score: 140
# Scores: (min: 15, avg: 163.32, max: 500)
#
# Run: 242, exploration: 0.01, score: 231
# Scores: (min: 15, avg: 164.19, max: 500)
#
# Run: 243, exploration: 0.01, score: 161
# Scores: (min: 15, avg: 164.24, max: 500)
#
# Run: 244, exploration: 0.01, score: 250
# Scores: (min: 15, avg: 165.14, max: 500)
#
# Run: 245, exploration: 0.01, score: 155
# Scores: (min: 15, avg: 165.07, max: 500)
#
# Run: 246, exploration: 0.01, score: 129
# Scores: (min: 15, avg: 164.88, max: 500)
#
# Run: 247, exploration: 0.01, score: 140
# Scores: (min: 15, avg: 164.76, max: 500)
#
# Run: 248, exploration: 0.01, score: 105
# Scores: (min: 15, avg: 164.13, max: 500)
#
# Run: 249, exploration: 0.01, score: 112
# Scores: (min: 15, avg: 163.55, max: 500)
#
# Run: 250, exploration: 0.01, score: 132
# Scores: (min: 15, avg: 163.26, max: 500)
#
# Run: 251, exploration: 0.01, score: 119
# Scores: (min: 36, avg: 164.3, max: 500)
#
# Run: 252, exploration: 0.01, score: 134
# Scores: (min: 36, avg: 164.37, max: 500)
#
# Run: 253, exploration: 0.01, score: 140
# Scores: (min: 39, avg: 165.41, max: 500)
#
# Run: 254, exploration: 0.01, score: 115
# Scores: (min: 39, avg: 165.05, max: 500)
#
# Run: 255, exploration: 0.01, score: 126
# Scores: (min: 39, avg: 165.02, max: 500)
#
# Run: 256, exploration: 0.01, score: 112
# Scores: (min: 39, avg: 164.83, max: 500)
#
# Run: 257, exploration: 0.01, score: 138
# Scores: (min: 39, avg: 164.98, max: 500)
#
# Run: 258, exploration: 0.01, score: 150
# Scores: (min: 39, avg: 165.44, max: 500)
#
# Run: 259, exploration: 0.01, score: 127
# Scores: (min: 39, avg: 165.28, max: 500)
#
# Run: 260, exploration: 0.01, score: 438
# Scores: (min: 39, avg: 167.83, max: 500)
#
# Run: 261, exploration: 0.01, score: 138
# Scores: (min: 39, avg: 167.57, max: 500)
#
# Run: 262, exploration: 0.01, score: 110
# Scores: (min: 39, avg: 166.27, max: 500)
#
# Run: 263, exploration: 0.01, score: 144
# Scores: (min: 39, avg: 165.85, max: 500)
#
# Run: 264, exploration: 0.01, score: 168
# Scores: (min: 39, avg: 166.29, max: 500)
#
# Run: 265, exploration: 0.01, score: 239
# Scores: (min: 39, avg: 166.76, max: 500)
#
# Run: 266, exploration: 0.01, score: 412
# Scores: (min: 39, avg: 169.55, max: 500)
#
# Run: 267, exploration: 0.01, score: 127
# Scores: (min: 39, avg: 169.26, max: 500)
#
# Run: 268, exploration: 0.01, score: 144
# Scores: (min: 39, avg: 168.84, max: 500)
#
# Run: 269, exploration: 0.01, score: 170
# Scores: (min: 39, avg: 169.14, max: 500)
#
# Run: 270, exploration: 0.01, score: 406
# Scores: (min: 39, avg: 171.58, max: 500)
#
# Run: 271, exploration: 0.01, score: 146
# Scores: (min: 39, avg: 171.27, max: 500)
#
# Run: 272, exploration: 0.01, score: 189
# Scores: (min: 39, avg: 170.75, max: 500)
#
# Run: 273, exploration: 0.01, score: 132
# Scores: (min: 39, avg: 170.17, max: 500)
#
# Run: 274, exploration: 0.01, score: 365
# Scores: (min: 39, avg: 171.76, max: 500)
#
# Run: 275, exploration: 0.01, score: 500
# Scores: (min: 39, avg: 175.31, max: 500)
#
# Run: 276, exploration: 0.01, score: 275
# Scores: (min: 39, avg: 176.57, max: 500)
#
# Run: 277, exploration: 0.01, score: 188
# Scores: (min: 39, avg: 176.64, max: 500)
#
# Run: 278, exploration: 0.01, score: 128
# Scores: (min: 39, avg: 176.28, max: 500)
#
# Run: 279, exploration: 0.01, score: 143
# Scores: (min: 39, avg: 175.49, max: 500)
#
# Run: 280, exploration: 0.01, score: 327
# Scores: (min: 39, avg: 176.63, max: 500)
#
# Run: 281, exploration: 0.01, score: 232
# Scores: (min: 39, avg: 177.61, max: 500)
#
# Run: 282, exploration: 0.01, score: 272
# Scores: (min: 39, avg: 177.95, max: 500)
#
# Run: 283, exploration: 0.01, score: 209
# Scores: (min: 39, avg: 177.57, max: 500)
#
# Run: 284, exploration: 0.01, score: 194
# Scores: (min: 39, avg: 177.98, max: 500)
#
# Run: 285, exploration: 0.01, score: 160
# Scores: (min: 39, avg: 177.95, max: 500)
#
# Run: 286, exploration: 0.01, score: 128
# Scores: (min: 39, avg: 177.93, max: 500)
#
# Run: 287, exploration: 0.01, score: 95
# Scores: (min: 39, avg: 177.18, max: 500)
#
# Run: 288, exploration: 0.01, score: 178
# Scores: (min: 39, avg: 177.27, max: 500)
#
# Run: 289, exploration: 0.01, score: 144
# Scores: (min: 39, avg: 176.92, max: 500)
#
# Run: 290, exploration: 0.01, score: 178
# Scores: (min: 39, avg: 177.12, max: 500)
#
# Run: 291, exploration: 0.01, score: 500
# Scores: (min: 39, avg: 180.35, max: 500)
#
# Run: 292, exploration: 0.01, score: 146
# Scores: (min: 39, avg: 179.89, max: 500)
#
# Run: 293, exploration: 0.01, score: 159
# Scores: (min: 39, avg: 179.48, max: 500)
#
# Run: 294, exploration: 0.01, score: 93
# Scores: (min: 39, avg: 177.99, max: 500)
#
# Run: 295, exploration: 0.01, score: 181
# Scores: (min: 39, avg: 178.64, max: 500)
#
# Run: 296, exploration: 0.01, score: 162
# Scores: (min: 39, avg: 176.37, max: 500)
#
# Run: 297, exploration: 0.01, score: 170
# Scores: (min: 39, avg: 174.02, max: 500)
#
# Run: 298, exploration: 0.01, score: 170
# Scores: (min: 39, avg: 173.01, max: 500)
#
# Run: 299, exploration: 0.01, score: 248
# Scores: (min: 39, avg: 173.22, max: 500)
#
# Run: 300, exploration: 0.01, score: 131
# Scores: (min: 39, avg: 172.68, max: 500)
#
# Run: 301, exploration: 0.01, score: 204
# Scores: (min: 39, avg: 172.08, max: 500)
#
# Run: 302, exploration: 0.01, score: 102
# Scores: (min: 39, avg: 170.62, max: 500)
#
# Run: 303, exploration: 0.01, score: 119
# Scores: (min: 39, avg: 170.63, max: 500)
#
# Run: 304, exploration: 0.01, score: 137
# Scores: (min: 39, avg: 170.97, max: 500)
#
# Run: 305, exploration: 0.01, score: 147
# Scores: (min: 39, avg: 171.37, max: 500)
#
# Run: 306, exploration: 0.01, score: 150
# Scores: (min: 39, avg: 171.63, max: 500)
#
# Run: 307, exploration: 0.01, score: 125
# Scores: (min: 39, avg: 171.19, max: 500)
#
# Run: 308, exploration: 0.01, score: 180
# Scores: (min: 39, avg: 171.48, max: 500)
#
# Run: 309, exploration: 0.01, score: 135
# Scores: (min: 39, avg: 167.83, max: 500)
#
# Run: 310, exploration: 0.01, score: 114
# Scores: (min: 39, avg: 167.54, max: 500)
#
# Run: 311, exploration: 0.01, score: 146
# Scores: (min: 39, avg: 168.17, max: 500)
#
# Run: 312, exploration: 0.01, score: 194
# Scores: (min: 39, avg: 167.75, max: 500)
#
# Run: 313, exploration: 0.01, score: 164
# Scores: (min: 39, avg: 167.99, max: 500)
#
# Run: 314, exploration: 0.01, score: 103
# Scores: (min: 39, avg: 168.56, max: 500)
#
# Run: 315, exploration: 0.01, score: 233
# Scores: (min: 39, avg: 168.3, max: 500)
#
# Run: 316, exploration: 0.01, score: 131
# Scores: (min: 39, avg: 168.33, max: 500)
#
# Run: 317, exploration: 0.01, score: 122
# Scores: (min: 39, avg: 168.63, max: 500)
#
# Run: 318, exploration: 0.01, score: 315
# Scores: (min: 39, avg: 168.4, max: 500)
#
# Run: 319, exploration: 0.01, score: 177
# Scores: (min: 39, avg: 168.53, max: 500)
#
# Run: 320, exploration: 0.01, score: 143
# Scores: (min: 39, avg: 168.74, max: 500)
#
# Run: 321, exploration: 0.01, score: 154
# Scores: (min: 39, avg: 167.15, max: 500)
#
# Run: 322, exploration: 0.01, score: 147
# Scores: (min: 39, avg: 167.55, max: 500)
#
# Run: 323, exploration: 0.01, score: 180
# Scores: (min: 39, avg: 168.2, max: 500)
#
# Run: 324, exploration: 0.01, score: 130
# Scores: (min: 39, avg: 168.25, max: 500)
#
# Run: 325, exploration: 0.01, score: 249
# Scores: (min: 39, avg: 169.64, max: 500)
#
# Run: 326, exploration: 0.01, score: 335
# Scores: (min: 39, avg: 171.98, max: 500)
#
# Run: 327, exploration: 0.01, score: 224
# Scores: (min: 39, avg: 172.95, max: 500)
#
# Run: 328, exploration: 0.01, score: 208
# Scores: (min: 39, avg: 173.94, max: 500)
#
# Run: 329, exploration: 0.01, score: 250
# Scores: (min: 39, avg: 175.29, max: 500)
#
# Run: 330, exploration: 0.01, score: 110
# Scores: (min: 39, avg: 175.04, max: 500)
#
# Run: 331, exploration: 0.01, score: 124
# Scores: (min: 39, avg: 175.01, max: 500)
#
# Run: 332, exploration: 0.01, score: 139
# Scores: (min: 39, avg: 175.91, max: 500)
#
# Run: 333, exploration: 0.01, score: 121
# Scores: (min: 39, avg: 175.95, max: 500)
#
# Run: 334, exploration: 0.01, score: 112
# Scores: (min: 39, avg: 175.85, max: 500)
#
# Run: 335, exploration: 0.01, score: 263
# Scores: (min: 39, avg: 178.02, max: 500)
#
# Run: 336, exploration: 0.01, score: 128
# Scores: (min: 93, avg: 178.91, max: 500)
#
# Run: 337, exploration: 0.01, score: 133
# Scores: (min: 93, avg: 179.15, max: 500)
#
# Run: 338, exploration: 0.01, score: 228
# Scores: (min: 93, avg: 180.21, max: 500)
#
# Run: 339, exploration: 0.01, score: 119
# Scores: (min: 93, avg: 179.65, max: 500)
#
# Run: 340, exploration: 0.01, score: 186
# Scores: (min: 93, avg: 180.36, max: 500)
#
# Run: 341, exploration: 0.01, score: 150
# Scores: (min: 93, avg: 180.46, max: 500)
#
# Run: 342, exploration: 0.01, score: 136
# Scores: (min: 93, avg: 179.51, max: 500)
#
# Run: 343, exploration: 0.01, score: 141
# Scores: (min: 93, avg: 179.31, max: 500)
#
# Run: 344, exploration: 0.01, score: 100
# Scores: (min: 93, avg: 177.81, max: 500)
#
# Run: 345, exploration: 0.01, score: 100
# Scores: (min: 93, avg: 177.26, max: 500)
#
# Run: 346, exploration: 0.01, score: 177
# Scores: (min: 93, avg: 177.74, max: 500)
#
# Run: 347, exploration: 0.01, score: 368
# Scores: (min: 93, avg: 180.02, max: 500)
#
# Run: 348, exploration: 0.01, score: 196
# Scores: (min: 93, avg: 180.93, max: 500)
#
# Run: 349, exploration: 0.01, score: 224
# Scores: (min: 93, avg: 182.05, max: 500)
#
# Run: 350, exploration: 0.01, score: 163
# Scores: (min: 93, avg: 182.36, max: 500)
#
# Run: 351, exploration: 0.01, score: 175
# Scores: (min: 93, avg: 182.92, max: 500)
#
# Run: 352, exploration: 0.01, score: 152
# Scores: (min: 93, avg: 183.1, max: 500)
#
# Run: 353, exploration: 0.01, score: 142
# Scores: (min: 93, avg: 183.12, max: 500)
#
# Run: 354, exploration: 0.01, score: 122
# Scores: (min: 93, avg: 183.19, max: 500)
#
# Run: 355, exploration: 0.01, score: 24
# Scores: (min: 24, avg: 182.17, max: 500)
#
# Run: 356, exploration: 0.01, score: 131
# Scores: (min: 24, avg: 182.36, max: 500)
#
# Run: 357, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 185.98, max: 500)
#
# Run: 358, exploration: 0.01, score: 123
# Scores: (min: 24, avg: 185.71, max: 500)
#
# Run: 359, exploration: 0.01, score: 190
# Scores: (min: 24, avg: 186.34, max: 500)
#
# Run: 360, exploration: 0.01, score: 211
# Scores: (min: 24, avg: 184.07, max: 500)
#
# Run: 361, exploration: 0.01, score: 150
# Scores: (min: 24, avg: 184.19, max: 500)
#
# Run: 362, exploration: 0.01, score: 171
# Scores: (min: 24, avg: 184.8, max: 500)
#
# Run: 363, exploration: 0.01, score: 272
# Scores: (min: 24, avg: 186.08, max: 500)
#
# Run: 364, exploration: 0.01, score: 190
# Scores: (min: 24, avg: 186.3, max: 500)
#
# Run: 365, exploration: 0.01, score: 205
# Scores: (min: 24, avg: 185.96, max: 500)
#
# Run: 366, exploration: 0.01, score: 208
# Scores: (min: 24, avg: 183.92, max: 500)
#
# Run: 367, exploration: 0.01, score: 217
# Scores: (min: 24, avg: 184.82, max: 500)
#
# Run: 368, exploration: 0.01, score: 97
# Scores: (min: 24, avg: 184.35, max: 500)
#
# Run: 369, exploration: 0.01, score: 109
# Scores: (min: 24, avg: 183.74, max: 500)
#
# Run: 370, exploration: 0.01, score: 151
# Scores: (min: 24, avg: 181.19, max: 500)
#
# Run: 371, exploration: 0.01, score: 194
# Scores: (min: 24, avg: 181.67, max: 500)
#
# Run: 372, exploration: 0.01, score: 105
# Scores: (min: 24, avg: 180.83, max: 500)
#
# Run: 373, exploration: 0.01, score: 231
# Scores: (min: 24, avg: 181.82, max: 500)
#
# Run: 374, exploration: 0.01, score: 193
# Scores: (min: 24, avg: 180.1, max: 500)
#
# Run: 375, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 180.1, max: 500)
#
# Run: 376, exploration: 0.01, score: 278
# Scores: (min: 24, avg: 180.13, max: 500)
#
# Run: 377, exploration: 0.01, score: 193
# Scores: (min: 24, avg: 180.18, max: 500)
#
# Run: 378, exploration: 0.01, score: 264
# Scores: (min: 24, avg: 181.54, max: 500)
#
# Run: 379, exploration: 0.01, score: 167
# Scores: (min: 24, avg: 181.78, max: 500)
#
# Run: 380, exploration: 0.01, score: 64
# Scores: (min: 24, avg: 179.15, max: 500)
#
# Run: 381, exploration: 0.01, score: 264
# Scores: (min: 24, avg: 179.47, max: 500)
#
# Run: 382, exploration: 0.01, score: 313
# Scores: (min: 24, avg: 179.88, max: 500)
#
# Run: 383, exploration: 0.01, score: 196
# Scores: (min: 24, avg: 179.75, max: 500)
#
# Run: 384, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 182.81, max: 500)
#
# Run: 385, exploration: 0.01, score: 192
# Scores: (min: 24, avg: 183.13, max: 500)
#
# Run: 386, exploration: 0.01, score: 55
# Scores: (min: 24, avg: 182.4, max: 500)
#
# Run: 387, exploration: 0.01, score: 14
# Scores: (min: 14, avg: 181.59, max: 500)
#
# Run: 388, exploration: 0.01, score: 116
# Scores: (min: 14, avg: 180.97, max: 500)
#
# Run: 389, exploration: 0.01, score: 144
# Scores: (min: 14, avg: 180.97, max: 500)
#
# Run: 390, exploration: 0.01, score: 235
# Scores: (min: 14, avg: 181.54, max: 500)
#
# Run: 391, exploration: 0.01, score: 500
# Scores: (min: 14, avg: 181.54, max: 500)
#
# Run: 392, exploration: 0.01, score: 204
# Scores: (min: 14, avg: 182.12, max: 500)
#
# Run: 393, exploration: 0.01, score: 452
# Scores: (min: 14, avg: 185.05, max: 500)
#
# Run: 394, exploration: 0.01, score: 232
# Scores: (min: 14, avg: 186.44, max: 500)
#
# Run: 395, exploration: 0.01, score: 208
# Scores: (min: 14, avg: 186.71, max: 500)
#
# Run: 396, exploration: 0.01, score: 139
# Scores: (min: 14, avg: 186.48, max: 500)
#
# Run: 397, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 186.5, max: 500)
#
# Run: 398, exploration: 0.01, score: 165
# Scores: (min: 14, avg: 186.45, max: 500)
#
# Run: 399, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 185.28, max: 500)
#
# Run: 400, exploration: 0.01, score: 119
# Scores: (min: 14, avg: 185.16, max: 500)
#
# Run: 401, exploration: 0.01, score: 314
# Scores: (min: 14, avg: 186.26, max: 500)
#
# Run: 402, exploration: 0.01, score: 213
# Scores: (min: 14, avg: 187.37, max: 500)
#
# Run: 403, exploration: 0.01, score: 140
# Scores: (min: 14, avg: 187.58, max: 500)
#
# Run: 404, exploration: 0.01, score: 148
# Scores: (min: 14, avg: 187.69, max: 500)
#
# Run: 405, exploration: 0.01, score: 149
# Scores: (min: 14, avg: 187.71, max: 500)
#
# Run: 406, exploration: 0.01, score: 223
# Scores: (min: 14, avg: 188.44, max: 500)
#
# Run: 407, exploration: 0.01, score: 114
# Scores: (min: 14, avg: 188.33, max: 500)
#
# Run: 408, exploration: 0.01, score: 282
# Scores: (min: 14, avg: 189.35, max: 500)
#
# Run: 409, exploration: 0.01, score: 146
# Scores: (min: 14, avg: 189.46, max: 500)
#
# Run: 410, exploration: 0.01, score: 365
# Scores: (min: 14, avg: 191.97, max: 500)
#
# Run: 411, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 192.07, max: 500)
#
# Run: 412, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 191.85, max: 500)
#
# Run: 413, exploration: 0.01, score: 144
# Scores: (min: 14, avg: 191.65, max: 500)
#
# Run: 414, exploration: 0.01, score: 86
# Scores: (min: 14, avg: 191.48, max: 500)
#
# Run: 415, exploration: 0.01, score: 14
# Scores: (min: 14, avg: 189.29, max: 500)
#
# Run: 416, exploration: 0.01, score: 263
# Scores: (min: 14, avg: 190.61, max: 500)
#
# Run: 417, exploration: 0.01, score: 17
# Scores: (min: 14, avg: 189.56, max: 500)
#
# Run: 418, exploration: 0.01, score: 27
# Scores: (min: 14, avg: 186.68, max: 500)
#
# Run: 419, exploration: 0.01, score: 122
# Scores: (min: 14, avg: 186.13, max: 500)
#
# Run: 420, exploration: 0.01, score: 202
# Scores: (min: 14, avg: 186.72, max: 500)
#
# Run: 421, exploration: 0.01, score: 248
# Scores: (min: 14, avg: 187.66, max: 500)
#
# Run: 422, exploration: 0.01, score: 391
# Scores: (min: 14, avg: 190.1, max: 500)
#
# Run: 423, exploration: 0.01, score: 371
# Scores: (min: 14, avg: 192.01, max: 500)
#
# Run: 424, exploration: 0.01, score: 153
# Scores: (min: 14, avg: 192.24, max: 500)
#
# Run: 425, exploration: 0.01, score: 255
# Scores: (min: 14, avg: 192.3, max: 500)
#
# Run: 426, exploration: 0.01, score: 173
# Scores: (min: 14, avg: 190.68, max: 500)
#
# Run: 427, exploration: 0.01, score: 125
# Scores: (min: 14, avg: 189.69, max: 500)
#
# Run: 428, exploration: 0.01, score: 119
# Scores: (min: 14, avg: 188.8, max: 500)
#
# Run: 429, exploration: 0.01, score: 257
# Scores: (min: 14, avg: 188.87, max: 500)
#
# Run: 430, exploration: 0.01, score: 500
# Scores: (min: 14, avg: 192.77, max: 500)
#
# Run: 431, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 192.84, max: 500)
#
# Run: 432, exploration: 0.01, score: 189
# Scores: (min: 14, avg: 193.34, max: 500)
#
# Run: 433, exploration: 0.01, score: 355
# Scores: (min: 14, avg: 195.68, max: 500)
#
# Solved in 333 runs, 433 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-2-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# # The first runs yielded between a 34 iteration being solved to this latest run which comes to a solution in 333 runs. There is  quite a difference in the results of the tests being run numerous times.
#
# # The goal of the agent is to learn and solve based on reward which means that the pole is kept in the upright position for the  maximum amount of time.
#
# # The various state values are: Cart position (x)
# # Cart velocity (x_dot)
# # Pole angle (theta)
# # Pole angular velocity (theta_dot)
#
# # The possible actions that can be taken by the agent include moving the cart to the right or left.
#
# # The algorithm that is used is Q learning. Q-learning is a machine learning approach that uses reinforcement learning to enable a model to learn and improve over time. (Dazeley, et al., 2022)
#
# # In this Q-learning example, experience replay involves storing the agent's experiences (state, action, reward, next state) in a replay buffer. During training, random batches of experiences are sampled from the buffer to update the Q-network, reducing the issues of correlated updates and increasing data efficiency. (Zhang, et al., 2021)
#
# # In the CartPole testing  The discount factor (gamma) determines the importance of future rewards in the agent's decision-making. A higher gamma values make the agent prioritize long-term rewards, while a lower value makes it focus more on short-term rewards. (Castaneda, et al., 2022)
#
# # Neural Network Architecture is the CartPole application would consist of Input layer with four neurons (corresponding to the four state values)
# # One or more hidden layers (with a suitable number of neurons and activation functions)
# # Output layer with two neurons (for the two possible actions)
# # Traditional distributed deep reinforcement learning (RL) commonly relies on exchanging the experience replay memory (RM) of each agent.
#
# # (Cha, et al., 2020)
# #
# # How does the neural network make the Q-learning algorithm more efficient?
# # Neural networks make Q-learning more efficient by enabling function
# # approximation. They can generalize Q-values across similar states which equates to greater efficiency.
#
# # A higher learning rate can lead to faster convergence but may result in instability or possibly overshooting.
# #  A lower learning rate can make learning more stable but slower.
#
#
# # References
# # Kurniawan, B., Vamplew, P., Papasimeon, M., Dazeley, R., & Foale, C. (2022). Discrete-to-deep reinforcement learning methods. Neural Computing & Applications, 34(3), 1713–1733. https://doi-org.ezproxy.snhu.edu/10.1007/s00521-021-06270-6
#
# # Zhang, C., Song, Q., & Meng, Z. (2021). Minibatch Recursive Least Squares Q-Learning. Computational Intelligence & Neuroscience, 1–9. https://doi-org.ezproxy.snhu.edu/10.1155/2021/5370281
#
# # Westenbroek, T., Castaneda, F., Agrawal, A., Sastry, S., & Sreenath, K. (2022). Lyapunov Design for Robust and Efficient Robotic Reinforcement Learning.
#
# # Cha, H., Park, J., Kim, H., Bennis, M., & Kim, S. (2020). Proxy Experience Replay: Federated Distillation for Distributed Reinforcement Learning. IEEE Intelligent Systems, Intelligent Systems, IEEE, IEEE Intell. Syst, 35(4), 94–101. https://doi-org.ezproxy.snhu.edu/10.1109/MIS.2020.2994942
